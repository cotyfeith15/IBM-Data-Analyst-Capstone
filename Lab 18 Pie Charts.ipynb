# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-02-20 17:40:10--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# 169.63.118.104ourses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)...
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  55.5MB/s    in 2.7s
#
# 2025-02-20 17:40:13 (55.5 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Count the occurrences of each database
database_counts = df['DatabaseWantToWorkWith'].value_counts()

# Get the top 5 most-desired databases
top_5_databases = database_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_databases, labels=top_5_databases.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Most Desired Databases to Work With')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Count the occurrences of each developer role
devtype_counts = df['DevType'].value_counts()

# Get the top 5 developer roles
top_5_devtypes = devtype_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_devtypes, labels=top_5_devtypes.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Developer Roles')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Count the occurrences of each operating system
opsys_counts = df['OpSysProfessional'].value_counts()

# Get the top operating systems (you can specify how many top systems you want, e.g., top 5)
top_opsys = opsys_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_opsys, labels=top_opsys.index, autopct='%1.1f%%', startangle=140)
plt.title('Top Operating Systems Used Professionally')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OpSysProfessional'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       2 import matplotlib.pyplot as plt
# ...

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Split the 'LanguageHaveWorkedWith' column to count individual languages
# Assuming each language is separated by a comma
language_counts = df['LanguageHaveWorkedWith'].str.split(',').explode().str.strip().value_counts()

# Get the top programming languages (you can specify how many top languages you want, e.g., top 5)
top_languages = language_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_languages, labels=top_languages.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Programming Languages Experienced By Respondents')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Split the 'NEWCollabToolsHaveWorkedWith' column to count individual tools
# Assuming each tool is separated by a comma
collab_tool_counts = df['NEWCollabToolsHaveWorkedWith'].str.split(',').explode().str.strip().value_counts()

# Get the top collaboration tools (you can specify how many top tools you want, e.g., top 5)
top_collab_tools = collab_tool_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_collab_tools, labels=top_collab_tools.index, autopct='%1.1f%%', startangle=140)
plt.title('Top Collaboration Tools Used by Respondents')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Split the 'LanguageAdmired' column to count individual languages
# Assuming each language is separated by a comma
admired_language_counts = df['LanguageAdmired'].str.split(',').explode().str.strip().value_counts()

# Get the top admired languages (you can specify how many top languages you want, e.g., top 5)
top_admired_languages = admired_language_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_admired_languages, labels=top_admired_languages.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Admired Programming Languages')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
# Print the column names
print("Column names in the DataFrame:")
print(df.columns.tolist())
# Out:
# Column names in the DataFrame:
# ...

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Split the 'WebframeWantToWorkWith' column to count individual frameworks
# Assuming each framework is separated by a comma
webframe_counts = df['WebframeWantToWorkWith'].str.split(',').explode().str.strip().value_counts()

# Get the top web frameworks (you can specify how many top frameworks you want, e.g., top 5)
top_webframes = webframe_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_webframes, labels=top_webframes.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Web Frameworks Respondents Want to Work With')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data into a DataFrame
# df = pd.read_sql_query("SELECT * FROM your_table", conn)

# Split the 'EmbeddedWantToWorkWith' column to count individual technologies
# Assuming each technology is separated by a comma
embedded_counts = df['EmbeddedWantToWorkWith'].str.split(',').explode().str.strip().value_counts()

# Get the top embedded technologies (you can specify how many top technologies you want, e.g., top 5)
top_embedded = embedded_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_embedded, labels=top_embedded.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Embedded Technologies Respondents Want to Work With')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
